# %%
# Import all the stuff that I need
from __future__ import division, print_function
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sys

sys.path.insert(1, r'./')
from detect_cusum import detect_cusum
from label_data import *
# Define Global Errors
ERROR_MAGNITUDE = 1111
ERROR_EXISTENCE = 2222
# Out:
# /usr/local/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2499: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)

# %% [markdown]
# ## [WEEK 7] Creation of different CUSUM Intervals

# %% [markdown]
# I realized by integrating minimum sample size that most of my sizes are small ~20 weeks. So we should get ~ 1 year and around ~ 3 year intervals as well. We may also try cutoff segments. For these large intervals, we make need the windowed CUSUM that we designed earlier.

# %% [markdown]
# ### 1. Midsize Section (~1 year) w/ Windowed Functionality w/o Cutoffs

# %% [markdown]
# We are going to have to rederive the equations including the important parts we need. Thus we have to change the interval AND we have to add windowed + cutoffs

# %%
from pickle import load
from pylab import *
data = load(open('../storage/final/full-processed-data.pkl', 'rb'))
index = load(open('../storage/final/full-processed-index.pkl', 'rb'))

# %%
# Search the data for the ticker 
tix = search_by_ticker(data, 'AA')
stock_tix = search_by_index(index, tix, 'Log Stock Return').astype('float32')
market_tix = search_by_index(index, tix, 'Log Index Return').astype('float32')

# %%
# Let's search for the set of best params with the midsize section constraints
disp = 0.25
combinations = []
# Try all the i, j combos for (threshold, drift)
for i in np.linspace(0, disp, 20):
    for j in np.linspace(0, disp, 20):
        ta, tai, taf, amp = detect_cusum(stock_tix, i, j, True, False, None)
        seg = [ta[k+1]-ta[k] for k in range(len(ta)-1)]
        seg = np.array(seg)
        # Make sure that there are no super small differenes, and none of them are 0
        if len(seg) >= int(ceil(len(stock_tix) / float(52))):
            continue
        combinations.append((i, j, ta, seg))
        
combinations.sort(key = lambda s: sum(s[3]))
chosen_threshold, chosen_drift, chosen_cuts, _ = combinations[::-1][0]

# %%
ta, tai, taf, amp = detect_cusum(stock_tix, chosen_threshold, chosen_drift, True, True, None)

# %%
ta
# Out:
# array([ 57, 224, 253, 261, 287, 301, 319, 320, 359, 362])

# %%
joined = []
indices, shifts = combinations[::-1][0][2], combinations[::-1][0][3]
indices = [0] + list(indices) + [len(stock_tix)]
base = indices[0]
joined.append(base)
for value in indices[1:]:
    if value - base > 40:
        joined.append(value)
        base = value
chosen_cuts = joined

# %%
ta = chosen_cuts
split_by_cusum = np.array([stock_tix[i:j] for i,j in zip(ta[0:len(ta)-1], ta[1:])])
split_by_market = np.array([market_tix[i:j] for i,j in zip(ta[0:len(ta)-1], ta[1:])])
ta
# Out:
# [0, 57, 224, 287, 359, 496]

# %%
MIN_SAMPLE_SIZE = 20
labels = [] # Resulting labels 
for i in range(len(ta)-1):
    start, end = ta[i], ta[i+1]
    while (end-start) >= MIN_SAMPLE_SIZE:
        tmp = tuple((start, int(one_tailed_two_sample_t_test(stock_tix[start:end], \
            market_tix[start:end], alpha=0.05))))
        labels.append(tmp)
        start += 1

# %% [markdown]
# ### 2. Large Section (~3 year) w/ Windowed Functionality w/o Cutoffs

# %% [markdown]
# Instead of 1 year stuff, let's try to do 3 year stuff. This way we have extremely long intervals! (which might be really interesting)

# %%
# Let's search for the set of best params with the midsize section constraints
disp = 0.25
combinations = []
# Try all the i, j combos for (threshold, drift)
for i in np.linspace(0, disp, 20):
    for j in np.linspace(0, disp, 20):
        ta, tai, taf, amp = detect_cusum(stock_tix, i, j, True, False, None)
        seg = [ta[k+1]-ta[k] for k in range(len(ta)-1)]
        seg = np.array(seg)
        # Make sure that there are no super small differenes, and none of them are 0
        if len(seg) >= int(ceil(len(stock_tix) / float(156))):
            continue
        combinations.append((i, j, ta, seg))
        
combinations.sort(key = lambda s: sum(s[3]))
chosen_threshold, chosen_drift, chosen_cuts, _ = combinations[::-1][0]

# %%
ta, tai, taf, amp = detect_cusum(stock_tix, chosen_threshold, chosen_drift, True, True, None)

# %%
ta
# Out:
# array([224, 261, 359, 362])

# %%
joined = []
indices, shifts = combinations[::-1][0][2], combinations[::-1][0][3]
indices = [0] + list(indices) + [len(stock_tix)]
base = indices[0]
joined.append(base)
for value in indices[1:]:
    if value - base > 40:
        joined.append(value)
        base = value
chosen_cuts = joined

# %%
ta = chosen_cuts
split_by_cusum = np.array([stock_tix[i:j] for i,j in zip(ta[0:len(ta)-1], ta[1:])])
split_by_market = np.array([market_tix[i:j] for i,j in zip(ta[0:len(ta)-1], ta[1:])])

# %%
ta
# Out:
# [0, 224, 359, 496]

# %%
MIN_SAMPLE_SIZE = 20
labels = [] # Resulting labels 
for i in range(len(ta)-1):
    start, end = ta[i], ta[i+1]
    while (end-start) >= MIN_SAMPLE_SIZE:
        tmp = tuple((start, int(one_tailed_two_sample_t_test(stock_tix[start:end], \
            market_tix[start:end], alpha=0.05))))
        labels.append(tmp)
        start += 1

# %% [markdown]
# ### Logic with Cutoffs?

# %% [markdown]
# One of the problems I should consider is should I split my labelling into small, medium, and large? I don't think it really matters if I do the WINDOWED because I will be captures small AND large. Also, I tihnk this really over-complicates things. Therefore, I will only do this if NOTHING i've done works here for SOM.

# %% [markdown]
# ### 3. Minimum Sample Problems?

# %%
def get_min_sample_size(market_data, start, end):
    # index_return = index_price_end/index_price_start (of investment horizon)
    market_return = market_data[end] / float(market_data[start])
    sigma = np.std(market_data[start:end])
    # sigma = sqrt(variance) = standard deviation
    tau = log((0.05 / 52 + market_return) / market_return) 
    n = (2.48 * sigma / float(tau))**2
    return n

# %%
get_min_sample_size(market_tix, 0, 5)
# Out:
# 28.282204401021808

# %% [markdown]
# Now in our function, we should try this out and see how many data points are still left over. Essentially, this shows that we need less data points given a more drastic change!

# %% [markdown]
# ### 4. We also need to formulize this stuff into functions and make sure they work for ALL stocks :)

# %% [markdown]
# <b>Functions to edit</b>:<br>
#
# 1) search_best_params<br>
# 2) cusum_consolidate<br>
# 3) split_by_cusum<br>

# %%
def cusum_consolidate(combinations, length):
    joined = []
    indices, shifts = combinations[2], combinations[3]
    indices = [0] + list(indices) + [length]
    base = indices[0]
    joined.append(base)
    for value in indices[1:]:
        if value - base > 40:
            joined.append(value)
            base = value
    chosen_cuts = joined
    return chosen_cuts

# %%
def search_best_params(stock_tix, targetRange, disp=0.25, plotting=False):
    # Let's search for the set of best params with the midsize section constraints
    combinations = []
    # Try all the i, j combos for (threshold, drift)
    for i in np.linspace(0, disp, 20):
        for j in np.linspace(0, disp, 20):
            ta, tai, taf, amp = detect_cusum(stock_tix, i, j, True, False, None)
            seg = [ta[k+1]-ta[k] for k in range(len(ta)-1)]
            seg = np.array(seg)
            # Make sure that there are no super small differenes, and none of them are 0
            if len(seg) >= int(ceil(len(stock_tix) / float(targetRange)))*1.5: # 1.5 is room for error
                continue
            combinations.append((i, j, ta, seg))
    if len(combinations) > 0:
        combinations.sort(key = lambda s: sum(s[3]))
        chosen_threshold, chosen_drift, chosen_cuts, _ = combinations[::-1][0]
        chosen_cuts = cusum_consolidate(combinations[::-1][0], len(stock_tix))
    else: 
        if disp < 5:
            print('Unable to find anything: Moving to displacement ' + str(disp+0.05))
            chosen_threshold, chosen_drift, chosen_cuts = search_best_params(stock_tix, 52, disp+0.05, False)
        else: # literally no findings... 
            print('Returning entire segment. Completely unable to find anything.')
            chosen_threshold, chosen_drift, chosen_cuts = None, None, ERROR_EXISTENCE
    return chosen_threshold, chosen_drift, chosen_cuts

# %%
def split_by_cusum(tix, stock_tix, market_tix, targetRange, plotting=False):
    if len(stock_tix) < 100:
        return None, None, ERROR_MAGNITUDE
    # Apply the CUSUM
    #print ('Finding Optimal Parameter...')
    threshold, drift, ta = search_best_params(stock_tix, targetRange)
    if type(ta) == int:
        return None, None, ERROR_EXISTENCE
    # Do the splitting
    split_by_cusum = np.array([stock_tix[i:j] for i,j in zip(ta[0:len(ta)-1], ta[1:])])
    split_by_market = np.array([market_tix[i:j] for i,j in zip(ta[0:len(ta)-1], ta[1:])])
    #print ('Complete: time horizons calculated and split successfully...')
    return split_by_cusum, split_by_market, ta

# %%
def wrapper_label_full_stock(data, index, tix, targetRange, style='standard'):
    MIN_SAMPLE_SIZE = 20
    if style not in ['recursive', 'standard']:
        return 'Error. Unknown style provided.'
    
    start = 1
    # Load the data
    part = search_by_ticker(data, tix)
    stock_tix = search_by_index(index, part, 'Log Stock Return').astype('float32')
    market_tix = search_by_index(index, part, 'Log Index Return').astype('float32')
    # Use the data for CUSUM
    split_stock, split_market, cracks = split_by_cusum(part, stock_tix, market_tix, targetRange, False)
    labels = []

    if len(stock_tix) < 100 or (type(cracks) == int and cracks == ERROR_MAGNITUDE):
        print("Error: not enough data for ticker %s." % str(tix))
        return None
    elif type(cracks) == int and cracks == ERROR_EXISTENCE:
        # Something broke... 
        print('Treating entire time data as segment for stock %s.' % str(tix))
        # Run this on the entire set
        tmp = tuple((0, int(one_tailed_two_sample_t_test(stock_tix, \
                    market_tix, alpha=0.05))))
        labels.append(tmp)
        return labels 
    
    for i in range(len(cracks)-1):
        start, end = cracks[i], cracks[i+1]
        if style == 'recursive':
            while (end-start) >= MIN_SAMPLE_SIZE:
                tmp = tuple((start, int(one_tailed_two_sample_t_test(stock_tix[start:end], \
                    market_tix[start:end], alpha=0.05))))
                labels.append(tmp)
                start += 1
        else:
            tmp = tuple((start, int(one_tailed_two_sample_t_test(stock_tix[start:end], \
                market_tix[start:end], alpha=0.05))))
            labels.append(tmp)
            start += 1
            
    return labels

# %% [markdown]
# Let's confirm that this correct. Compare to the other values we used before.

# %% [markdown]
# #### Let's try midsize example

# %%
labels = wrapper_label_full_stock(data, index, 'AA', 52, 'recursive')
# Out:
# [0, 57, 224, 287, 359, 496]

# %% [markdown]
# #### Let's try large size example

# %%
labels = wrapper_label_full_stock(data, index, 'AA', 156, 'recursive')
# Out:
# [0, 224, 359, 496]

# %% [markdown]
# ### 5. We need to actually label these data points (midsize & larger size)

# %% [markdown]
# Load all the data and for each ticker, run the mid-size and large size wrapper.

# %%
from scipy.stats import ttest_ind

# %%
# Basically same thing but with two samples.
def one_tailed_two_sample_t_test(data1, data2, alpha=0.05):
    t_stat, prob = ttest_ind(data1, data2, equal_var=True)
    result = 1 if (t_stat > 0 and prob / 2 < alpha) else 0
    return result

# %%
def one_tailed_two_sample_t_test(data1, data2, alpha=0.05):
    normality1, normality2 = am_i_normal(data1), am_i_normal(data2)
    if normality1 and normality2:
        t_stat, prob = ttest_ind(data1, data2, equal_var=True)
        # Greater than hypothesis
        result = 1 if (t_stat > 0 and prob / 2 < alpha) else 0
    else:
        u_stat, prob = mannwhitneyu(data1, data2)
        if prob < alpha:
        # All I know at this point is that the distributions are distinct. 
        # I have to compare raw medians to know which way
        # Let data1 be stock data
            result = (np.median(data1) > np.median(data2))
        else:
            result = 0  
    return result

# %%
tickers = unique(data[:, 0])

# %% [markdown]
# <b>YaY!</b> Confirmed that the 52 (1 year divisions work)<br>
# <b>YaY!</b> Confirmed that the 156 (3 year divisions work)

# %%
vectors_labels = []
for i in tickers:
    print('Running %s... Complete.' % i)
    vectors_labels.append(wrapper_label_full_stock(data, index, i, 52, 'recursive'))
# Out:
# Running A... Complete.
# Running AA... Complete.
# Running AAN... Complete.
# Running AAON... Complete.
# Running AAP... Complete.
# Running AAPL... Complete.
# Running AAV... Complete.
# Running AAWW... Complete.
# Running ABAX... Complete.
# Running ABC... Complete.
# Running ABCO... Complete.
# Running ABG... Complete.
# Running ABIO... Complete.
# Running ABM... Complete.
# Running ABMD... Complete.
# Running ABT... Complete.
# Running ABTL... Complete.
# Running ABX... Complete.
# Running ACAD... Complete.
# Unable to find anything: Moving to displacement 0.3
# Running ACAT... Complete.
# Running ACCO... Complete.
# Running ACET... Complete.
# Running ACFN... Complete.
# Running ACH... Complete.
# Running ACHN... Complete.
# Running ACI... Complete.
# Running ACIW... Complete.
# Running ACLS... Complete.
# Running ACM... Complete.
# Running ACN... Complete.
# Running ACOR... Complete.
# Running ACPW... Complete.
# Running ACT... Complete.
# Running ACTG... Complete.
# ...

# %%
midsize_label_vectors_labels = np.array(vectors_labels)
import pickle
pickle.dump(midsize_label_vectors_labels, open('./calculated_midsize_vectors_labels.pkl', 'wb'))

# %%
vectors_labels = []
for i in tickers:
    print('Running %s... Complete.' % i)
    vectors_labels.append(wrapper_label_full_stock(data, index, i, 156, 'recursive'))
# Out:
# Running A... Complete.
# Running AA... Complete.
# Running AAN... Complete.
# Running AAON... Complete.
# Running AAP... Complete.
# Running AAPL... Complete.
# Running AAV... Complete.
# Running AAWW... Complete.
# Running ABAX... Complete.
# Running ABC... Complete.
# Running ABCO... Complete.
# Running ABG... Complete.
# Running ABIO... Complete.
# Unable to find anything: Moving to displacement 0.3
# Running ABM... Complete.
# Running ABMD... Complete.
# Running ABT... Complete.
# Running ABTL... Complete.
# Running ABX... Complete.
# Running ACAD... Complete.
# Unable to find anything: Moving to displacement 0.3
# Running ACAT... Complete.
# Running ACCO... Complete.
# Unable to find anything: Moving to displacement 0.3
# Running ACET... Complete.
# Running ACFN... Complete.
# Running ACH... Complete.
# Running ACHN... Complete.
# Unable to find anything: Moving to displacement 0.3
# Running ACI... Complete.
# Running ACIW... Complete.
# Running ACLS... Complete.
# ...

# %%
large_label_vectors_labels = np.array(vectors_labels)
pickle.dump(large_label_vectors_labels, open('./calculated_large_vectors_labels.pkl', 'wb'))

# %% [markdown]
# #### Take the vectors and then actually pull out the indices with the label

# %%
def cherry_pick_all_labelled_vector(tickers, vectors_labels, data):
    complete = []
    count = 0
    for tix,vec in zip(tickers, vectors_labels):
        if vec != None:
            # Get all the data
            part = search_by_ticker(data, tix)
            # Map the data into feature-vector:label form
            tmp = [tuple((part[i][3:].astype('float32'), j)) for i,j in vec]
            complete = complete + tmp
            count = count+1
    return np.array(complete)

# %%
tmp = cherry_pick_all_labelled_vector(tickers, midsize_label_vectors_labels, data)
tmp = np.array(tmp)

# %%
tmp2 = cherry_pick_all_labelled_vector(tickers, large_label_vectors_labels, data)
tmp2 = np.array(tmp2)

# %%
midsize_vectors, midsize_labels = np.array([i[0] for i in tmp]), np.array([i[1] for i in tmp])
large_vectors, large_labels = np.array([i[0] for i in tmp2]), np.array([i[1] for i in tmp2])

# %%
from pickle import dump
dump(midsize_vectors, open('./SOMPY/separate_midsize_feature_vectors.pkl', 'wb'))
dump(midsize_labels, open('./SOMPY/separate_midsize_feature_labels.pkl', 'wb'))
dump(large_vectors, open('./SOMPY/separate_large_feature_vectors.pkl', 'wb'))
dump(large_labels, open('./SOMPY/separate_large_feature_labels.pkl', 'wb'))
